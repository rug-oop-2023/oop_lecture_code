# %% [markdown]
# Prevents a user from creating an object of that class
# + compels a user to override abstract methods in a child class

# %% [markdown]
# abstract class = a class which contains one or more abstract methods.
# abstract method = a method that has a declaration but does not have an implementation.

# %%
class Vehicle:
    def go(self):
        pass

class Car(Vehicle):
    def go(self):
        print("You drive the car")

class Motorcycle(Vehicle):

    def go(self):
        print("You ride the motorcycle")

vehicle = Vehicle()
car = Car()
motorcycle = Motorcycle()

vehicle.go()
car.go()
motorcycle.go()
# Out:
# You drive the car
# You ride the motorcycle

# %% [markdown]
# Note that vehicle did not print anything.

# %% [markdown]
# We make vehicle been an abstract class. This prevents our user from creating an object direct from vehicles.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def go(self):
        pass

class Car(Vehicle):
    def go(self):
        print("You drive the car")

class Motorcycle(Vehicle):

    def go(self):
        print("You ride the motorcycle")

vehicle = Vehicle()
car = Car()
motorcycle = Motorcycle()

vehicle.go()
car.go()
motorcycle.go()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# g:\My Drive\Artificial_Inteligence\Courses\OOP\Coding\Ch6\03_brocade.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a>     def go(self):
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a>         print("You ride the motorcycle")
# ---> <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a> vehicle = Vehicle()
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> car = Car()
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> motorcycle = Motorcycle()
#
# TypeError: Can't instantiate abstract class Vehicle with abstract method go

# %% [markdown]
# Note the TypeError: Can't instantiate abstract class Vehicle with abstract method go

# %% [markdown]
# abstract class = a class which contains one or more abstract methods.
# abstract method = a method that has a declaration but does not have an implementation.
#
# If remove the abstract method, the object vehicle can still be created.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    pass

class Car(Vehicle):
    def go(self):
        print("You drive the car")

class Motorcycle(Vehicle):

    def go(self):
        print("You ride the motorcycle")

vehicle = Vehicle()
car = Car()
motorcycle = Motorcycle()


car.go()
motorcycle.go()
# Out:
# You drive the car
# You ride the motorcycle

# %% [markdown]
# What if we remove the decorator @abstractmethod? (It allows the code to run as well)

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    def go(self):
        pass

class Car(Vehicle):
    def go(self):
        print("You drive the car")

class Motorcycle(Vehicle):

    def go(self):
        print("You ride the motorcycle")

vehicle = Vehicle()
car = Car()
motorcycle = Motorcycle()

vehicle.go()
car.go()
motorcycle.go()
# Out:
# You drive the car
# You ride the motorcycle

# %% [markdown]
# + compels a user to override abstract methods in a child class
# abstract method = a method that has a declaration but does not have an implementation.
#
# Let's forget to implement the go method in the Motorcycle class

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def go(self):
        pass

class Car(Vehicle):
    def go(self):
        print("You drive the car")

class Motorcycle(Vehicle):

    pass

# vehicle = Vehicle()
car = Car()
motorcycle = Motorcycle()

# vehicle.go()
car.go()
motorcycle.go()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# g:\My Drive\Artificial_Inteligence\Courses\OOP\Coding\Ch6\03_brocade.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#X16sZmlsZQ%3D%3D?line=15'>16</a> # vehicle = Vehicle()
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#X16sZmlsZQ%3D%3D?line=16'>17</a> car = Car()
# ---> <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#X16sZmlsZQ%3D%3D?line=17'>18</a> motorcycle = Motorcycle()
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#X16sZmlsZQ%3D%3D?line=19'>20</a> # vehicle.go()
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Artificial_Inteligence/Courses/OOP/Coding/Ch6/03_brocade.ipynb#X16sZmlsZQ%3D%3D?line=20'>21</a> car.go()
#
# TypeError: Can't instantiate abstract class Motorcycle with abstract method go

# %% [markdown]
# TypeError: Can't instantiate abstract class Motorcycle with abstract method go

# %% [markdown]
# Let's create a stop method

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def go(self):
        pass

    @abstractmethod
    def stop(self):
        pass

class Car(Vehicle):
    def go(self):
        print("You drive the car")

    def stop(self):
        print("This car is stopped.")

class Motorcycle(Vehicle):
    def go(self):
        print("You ride the motorcycle")

    # def stop(self):
    #     print("This motorcycle is stopped.")

# vehicle = Vehicle()
car = Car()
motorcycle = Motorcycle()

# vehicle.go()
car.go()
motorcycle.go()

car.stop()
motorcycle.stop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-123353b19ea0> in <cell line: 28>()
#      26 # vehicle = Vehicle()
#      27 car = Car()
# ---> 28 motorcycle = Motorcycle()
#      29
#      30 # vehicle.go()
#
# TypeError: Can't instantiate abstract class Motorcycle with abstract method stop
